# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadkhadafifadilah/pembelajaran-C-fundamental/blob/main/learn%201-python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# materi pertama pembelajaran tentang python

# %% [markdown]
# materi pertama pembelejaran tentang python

# %%
a=6
b=7
c=a+b
print (c)
# Out:
# 13
